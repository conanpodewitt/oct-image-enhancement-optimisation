# %%
# Imports

import numpy as np
import imageio.v3 as iio

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.bezier as mbezier
from sklearn.metrics.pairwise import euclidean_distances
from scipy.stats import norm

rng = np.random.default_rng()
Path = mpath.Path
mpl.rcParams['figure.dpi']= 72 #size of images

# %%
# Global variables

IMAGE_DIR = 'images'
IMAGE_NAME='original'
MASK = [320, 560, 160, 880] # ymin ymax xmin xmax

# %%
# Read, crop and display image and stats

def crop (image, mask):
    h, w = np.shape(image)
    return image[max(mask[0],0):min(mask[1],h), max(mask[2],0):min(mask[3],w)]

def prep_image (imdir, imname, mask):
    print("Image name (shape) (intensity max, min, mean, std)\n")
    image = np.flipud(crop(iio.imread(imdir+'/'+imname+".png"), mask))
    print("{} {} ({}, {}, {}, {})".format(imname, np.shape(image), np.max(image), np.min(image), round(np.mean(image),1), round(np.std(image),1)))
    plt.imshow(image, vmin=0, vmax=255, cmap='gray', origin='lower') # use vmin and vmax to stop imshow from scaling
    plt.show()
    return image

image = prep_image(IMAGE_DIR, IMAGE_NAME, MASK)
# Out:
# Image name (shape) (intensity max, min, mean, std)
#
# original (240, 720) (210, 0, 49.3, 34.8)

# %%
class Camo_Worm:
    def __init__(self, x, y, r, theta, deviation_r, deviation_gamma, width, colour):
        self.x = x
        self.y = y
        self.r = r
        self.theta = theta
        self.dr = deviation_r
        self.dgamma = deviation_gamma
        self.width = width
        self.colour = colour
        p0 = [self.x - self.r * np.cos(self.theta), self.y - self.r * np.sin(self.theta)]
        p2 = [self.x + self.r * np.cos(self.theta), self.y + self.r * np.sin(self.theta)]
        p1 = [self.x + self.dr * np.cos(self.theta + self.dgamma), self.y + self.dr * np.sin(self.theta + self.dgamma)]
        self.bezier = mbezier.BezierSegment(np.array([p0, p1, p2]))
    def control_points(self):
        return self.bezier.control_points

    def path(self):
        return mpath.Path(self.control_points(), [Path.MOVETO, Path.CURVE3, Path.CURVE3])

    def patch(self):
        return mpatches.PathPatch(self.path(), fc='None', ec=str(self.colour), lw=self.width, capstyle='round')

    def intermediate_points(self, intervals=None):
        if intervals is None:
            intervals = max(3, int(np.ceil(self.r / 8)))
        return self.bezier.point_at_t(np.linspace(0, 1, intervals))

    def approx_length(self):
        intermediates = self.intermediate_points()
        eds = euclidean_distances(intermediates, intermediates)
        return np.sum(np.diag(eds, 1))

    def colour_at_t(self, t, image):
        intermediates = np.int64(np.round(np.array(self.bezier.point_at_t(t)).reshape(-1, 2)))
        colours = [image[point[0], point[1]] for point in intermediates]
        return np.array(colours) / 255

    # Added size and distance_to methods to the camo worm class to return worm size and distance between worms
    def size(self):
        return self.r
    
    def width(self):
        return width.r

    # Distance function calculated using Euclidean distance
    def distance_to(self, other_worm):
        distance = ((self.x - other_worm.x) ** 2 + (self.y - other_worm.y) ** 2) ** 0.5
        return distance

    # testing colour cost function
    def color_similarity(self, background_color):
        similarity = np.linalg.norm(self.colour - background_color)
        return similarity



    def average_background_color(self, image, radius):
        # Convert the coordinates to integers
        min_y = int(max(0, self.y - radius))
        max_y = int(min(image.shape[0], self.y + radius))
        min_x = int(max(0, self.x - radius))
        max_x = int(min(image.shape[1], self.x + radius))

        # Slice the image using integer indices
        background_pixels = image[min_y:max_y, min_x:max_x]

        # Calculate the average color
        avg_color = np.mean(background_pixels, axis=(0, 1))
        return avg_color

# %%
class Drawing:
    def __init__ (self, image):
        self.fig, self.ax = plt.subplots()
        self.image = image
        self.im = self.ax.imshow(self.image, cmap='gray', origin='lower')

    def add_patches(self, patches):
        try:
            for patch in patches:
                self.ax.add_patch(patch)
        except TypeError:
            self.ax.add_patch(patches)

    def add_dots(self, points, radius=4, **kwargs):
        try:
            for point in points:
                self.ax.add_patch(mpatches.Circle((point[0],point[1]), radius, **kwargs))
        except TypeError:
            self.ax.add_patch(mpatches.Circle((points[0],points[1]), radius, **kwargs))

    def add_worms(self, worms):
        try:
            self.add_patches([w.patch() for w in worms])
        except TypeError:
            self.add_patches([worms.patch()])

    def show(self, save=None):
        if save is not None:
            plt.savefig(save)
        plt.show()

# %%
def random_worm(imshape, init_params):
    (ylim, xlim) = imshape
    midx = xlim * rng.random()
    midy = ylim * rng.random()
    r = init_params[0] * np.abs(rng.standard_normal())
    theta = rng.random() * np.pi
    dr = init_params[1] * np.abs(rng.standard_normal())
    dgamma = rng.random() * np.pi
    colour = rng.random()
    width = init_params[2] * rng.standard_gamma(3)
    return Camo_Worm(midx, midy, r, theta, dr, dgamma, width, colour)

# %%
import numpy as np

def initialize_population(population_size):
    population = []
    for _ in range(population_size):
        threshold = np.random.uniform(0, 100)
        population.append([threshold])  # Wrap each threshold in a list
    return population

def fitness(threshold):
    # Fitness function: minimize the threshold value
    return threshold[0]  # Return the threshold value

def crossover(population):
    # Select two distinct parents from the population
    parent_indices = np.random.choice(len(population.tostring()), size=2, replace=False)
    return parent_indices

def mutate(individual, mutation_rate):
    if np.random.rand() < mutation_rate:
        # Apply mutation with some randomness
        individual[0] = np.random.uniform(0, 100)
    return individual

def distance_constraint(new_worm, existing_worms, threshold):
    for worm in existing_worms:
        if new_worm.distance_to(worm) < threshold[0]:  # Access the threshold value
            return False
    return True

def optimize(population_size, mutation_rate, generations, existing_worms):
    # Initialize the population with random thresholds
    population = np.random.uniform(0, 1, size=(population_size,))

    # Evolutionary loop
    for _ in range(generations):
        # Select parents for crossover
        parent_indices = crossover(population)

        # Perform crossover
        crossover_point = np.random.randint(1, len(population[0]))  # Choose a random crossover point
        child = np.concatenate((population[parent_indices[0]][:crossover_point], 
                                population[parent_indices[1]][crossover_point:]))
        
        # Perform mutation
        if np.random.rand() < mutation_rate:
            mutation_point = np.random.randint(len(child))
            child[mutation_point] = np.random.rand()

        # Evaluate fitness of child
        child_fitness = fitness(child)

        # Replace worst individual in the population if child is better
        if child_fitness > min_fitness:
            population[np.argmin(fitness)] = child

    # Return the best threshold found
    return population[np.argmax(fitness)]



# Example usage
population_size = 50
mutation_rate = 0.1
generations = 100
existing_worms = []  # Your existing worms here
best_threshold = optimize(population_size, mutation_rate, generations, existing_worms)
print("Best Threshold:", best_threshold[0])  # Access the threshold value
# Out:
# C:\Users\Dennis\AppData\Local\Temp/ipykernel_28468/3455515919.py:16: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   parent_indices = np.random.choice(len(population.tostring()), size=2, replace=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28468/3455515919.py in <module>
#      65 generations = 100
#      66 existing_worms = []  # Your existing worms here
# ---> 67 best_threshold = optimize(population_size, mutation_rate, generations, existing_worms)
#      68 print("Best Threshold:", best_threshold[0])  # Access the threshold value
#
# ~\AppData\Local\Temp/ipykernel_28468/3455515919.py in optimize(population_size, mutation_rate, generations, existing_worms)
#      39
#      40         # Perform crossover
# ---> 41         crossover_point = np.random.randint(1, len(population[0]))  # Choose a random crossover point
#      42         child = np.concatenate((population[parent_indices[0]][:crossover_point],
#      43                                 population[parent_indices[1]][crossover_point:]))
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
def initialise_clew(size, imshape, init_params):
    clew = []
    while True:
        new_worm = random_worm(imshape, init_params)
        if distance_constraint(new_worm, clew) and size_constraint(new_worm) and color_constraint(new_worm, image):
            clew.append(new_worm)
            if len(clew) == size:
                return clew

# %%
# Set Genetic Algorithm parameters
population_size = 50
mutation_rate = 0.1
generations = 100

# Create an instance of the Genetic Algorithm
genetic_algo = GeneticAlgorithm(population_size, mutation_rate, generations)

# Start the optimization process
best_threshold = genetic_algo.optimize(imshape, )

# Output the best threshold found by the genetic algorithm
print("Best Threshold:", best_threshold)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28468/4287836319.py in <module>
#       8
#       9 # Start the optimization process
# ---> 10 best_threshold = genetic_algo.optimize()
#      11
#      12 # Output the best threshold found by the genetic algorithm
#
# TypeError: optimize() missing 2 required positional arguments: 'imshape' and 'existing_worms'

# %%
# Initialise clew and draw
image = prep_image(IMAGE_DIR, IMAGE_NAME, MASK)

drawing = Drawing(image)
drawing.add_worms(clew)
drawing.show()
# Out:
# Image name (shape) (intensity max, min, mean, std)
#
# original (240, 720) (210, 0, 49.3, 34.8)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25544/3624966543.py in <module>
#       3
#       4 drawing = Drawing(image)
# ----> 5 drawing.add_worms(clew)
#       6 drawing.show()
#
# ~\AppData\Local\Temp/ipykernel_25544/1937654457.py in add_worms(self, worms)
#      21     def add_worms(self, worms):
#      22         try:
# ---> 23             self.add_patches([w.patch() for w in worms])
#      24         except TypeError:
#      25             self.add_patches([worms.patch()])
#
# ~\AppData\Local\Temp/ipykernel_25544/1937654457.py in <listcomp>(.0)
#      21     def add_worms(self, worms):
#      22         try:
# ---> 23             self.add_patches([w.patch() for w in worms])
#      24         except TypeError:
#      25             self.add_patches([worms.patch()])
#
# ~\AppData\Local\Temp/ipykernel_25544/89462305.py in patch(self)
#      41
#      42     def patch(self):
# ---> 43         return mpatches.PathPatch(self.path(), fc='None', ec=str(self.colour), lw=self.width, capstyle='round')
#      44
#      45     def intermediate_points(self, intervals=None):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, path, **kwargs)
#     927         %(Patch_kwdoc)s
#     928         """
# --> 929         super().__init__(**kwargs)
#     930         self._path = path
#     931
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#     106
#     107         if len(kwargs):
# --> 108             self.update(kwargs)
#     109
#     110     def get_verts(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
# -> 1064                     ret.append(func(v))
#    1065         if ret:
#    1066             self.pchanged()
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in method(self, *args, **kwargs)
#    1923         @functools.wraps(getattr(cls, name))
#    1924         def method(self, *args, **kwargs):
# -> 1925             return getattr(self, name)(*args, **kwargs)
#    1926         return method
#    1927
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in set_edgecolor(self, color)
#     348         """
#     349         self._original_edgecolor = color
# --> 350         self._set_edgecolor(color)
#     351
#     352     def _set_facecolor(self, color):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _set_edgecolor(self, color)
#     334                 set_hatch_color = False
#     335
# --> 336         self._edgecolor = colors.to_rgba(color, self._alpha)
#     337         if set_hatch_color:
#     338             self._hatch_color = self._edgecolor
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     204         rgba = None
#     205     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 206         rgba = _to_rgba_no_colorcycle(c, alpha)
#     207         try:
#     208             _colors_full_map.cache[c, alpha] = rgba
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     271         else:
#     272             if not (0 <= c <= 1):
# --> 273                 raise ValueError(
#     274                     f"Invalid string grayscale value {orig_c!r}. "
#     275                     f"Value must be within 0-1 range")
#
# ValueError: Invalid string grayscale value '26.89'. Value must be within 0-1 range
